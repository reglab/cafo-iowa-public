# %% [markdown]
# # create satellite figures for flow chart

# %%
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
import numpy as np
import os
import sys
import warnings

import cafo_iowa.db.session as s
from cafo_iowa.estimate.estimate import load_and_process_facilities

from cafo_iowa.utils.visualize import plot_facility_example

# %%
facilities = load_and_process_facilities(uncertainty=False)

# %%
for i in [11, 13, 14, 16]:
    facility_id = facilities.iloc[i].facility_id
    plot_facility_example(
        facilities.iloc[i],
        show_text=False,
        show_scale=False,
        show_facility=True,
        buffer=250,
        show_legend=False,
        save_path=f"output/plots/facility_{facility_id}_image.png",
        figsize=(2, 2),
    )
